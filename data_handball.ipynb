# %%
# import libraries
import pandas as pd
import re

# %%
# load csv file to variable df as DataFrame
df = pd.read_csv('/Users/admin/database/data.csv')

# %%
# check how many rows and columns we have in file
df.shape
# Out:
# (187220, 10)

# %%
# display basic information (type, nullability, count) about our file
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187220 entries, 0 to 187219
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   187220 non-null  int64
#  1   COUNTRY      187220 non-null  object
#  2   LINK         187220 non-null  object
#  3   COMPETITION  187220 non-null  object
#  4   TEAMS        187220 non-null  object
#  5   RESULT       187220 non-null  object
#  6   HOME         130306 non-null  float64
#  7   DRAW         130306 non-null  float64
#  8   AWAY         130306 non-null  float64
#  9   DATE         187220 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 14.3+ MB

# %%
# show first 3 records
df.head(3)
# Out:
#    Unnamed: 0  COUNTRY                           LINK COMPETITION  \
# 0           0  Germany  /handball/germany/bundesliga/  bundesliga
# 1           1  Germany  /handball/germany/bundesliga/  bundesliga
# 2           2  Germany  /handball/germany/bundesliga/  bundesliga
#
#                          TEAMS RESULT  HOME   DRAW  AWAY        DATE
# 0        Bergischer - Erlangen  29:30  1.50   8.58  3.28  11.06.2023
# 1  Flensburg-H. - Rhein-Neckar  34:31  1.45   9.37  3.47  11.06.2023
# 2             Goppingen - Kiel  27:34  5.54  12.16  1.22  11.06.2023

# %%
# drop 2 columns which aren't necessary 
# - Unnamed:0 is ID from our database - now is our index automatic generated 
# - LINK has the same information which we can found COUNTRY and COMPETITION
df.drop(['Unnamed: 0','LINK'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    COUNTRY COMPETITION                        TEAMS RESULT  HOME   DRAW  AWAY  \
# 0  Germany  bundesliga        Bergischer - Erlangen  29:30  1.50   8.58  3.28
# 1  Germany  bundesliga  Flensburg-H. - Rhein-Neckar  34:31  1.45   9.37  3.47
# 2  Germany  bundesliga             Goppingen - Kiel  27:34  5.54  12.16  1.22
# 3  Germany  bundesliga     Hamm-Westfalen - Leipzig  28:33  4.64  10.57  1.29
# 4  Germany  bundesliga   HSG Wetzlar - SC Magdeburg  30:35  6.38  12.85  1.18
#
#          DATE
# 0  11.06.2023
# 1  11.06.2023
# 2  11.06.2023
# 3  11.06.2023
# 4  11.06.2023

# %%
# find value in column DATE with different mask than DD.MM.YYYY and drop it by index
# this step is obligatory because sometime when we scrape we didn't found 1 of 3 ODDS then ODD which we found was put in column DATE
i=0
for index, row in df.iterrows():
    if not bool(re.match(r'^\d{2}\.\d{2}\.\d{4}$', row['DATE'])):
        df.drop(index=index, inplace=True)
        i+=1
    else:
        pass
    
print(f'{i} records was dropped')
# Out:
# 8 records was dropped

# %%
# now we can convert DATE from object to datetime
df['DATE'] = pd.to_datetime(df['DATE'], format='%d.%m.%Y', infer_datetime_format=True)

# %%
# we can see that 8 records mentioned above was dropped (invalid format of DATE) and type of DATE was changed
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187212 entries, 0 to 187219
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   COUNTRY      187212 non-null  object
#  1   COMPETITION  187212 non-null  object
#  2   TEAMS        187212 non-null  object
#  3   RESULT       187212 non-null  object
#  4   HOME         130306 non-null  float64
#  5   DRAW         130306 non-null  float64
#  6   AWAY         130306 non-null  float64
#  7   DATE         187212 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 12.9+ MB

# %%
# below we want to find some incorrect value in RESULT column
# RESULT of fixture should look like for exmaple 22:21 - so char ':' is necessary
# so find RESULT without this char and count values from this COLUMN
df.loc[~df['RESULT'].str.contains(':'),'RESULT'].count()
# Out:
# 4203

# %%
# we see that we have 4203 value with invalid result
# CAN. - CANCEL - 4084
# WO. - WALKOVER - 93
# AWA. - AWARDED - 21
# POSTP - POSTPONED - 3
df.loc[~df['RESULT'].str.contains(':'),'RESULT'].value_counts()
# Out:
# CAN.      4084
# WO.         93
# AWA.        21
# POSTP.       5
# Name: RESULT, dtype: int64

# %%
# it isn't necessary to further analyze this records so we can remove it from our DataFrame
df=df[~df['RESULT'].isin(['CAN.','WO.','AWA.','POSTP.'])]

# %%
# we want to spli our result to 2 columns - column with home_team score and away_team score
# we should check that char : appear only once in this column - because we want to split it by this char
for index, row in df.iterrows():
    if len(row['RESULT'].split(':')) != 2:
        print(index)

# %%
# create 2 new columns to split RESULT by :
df[['H_score', 'A_score']] = df['RESULT'].str.split(':',expand=True)

# %%
# check actual status od DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183009 entries, 0 to 187219
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   COUNTRY      183009 non-null  object
#  1   COMPETITION  183009 non-null  object
#  2   TEAMS        183009 non-null  object
#  3   RESULT       183009 non-null  object
#  4   HOME         130152 non-null  float64
#  5   DRAW         130152 non-null  float64
#  6   AWAY         130152 non-null  float64
#  7   DATE         183009 non-null  datetime64[ns]
#  8   H_score      183009 non-null  object
#  9   A_score      183009 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(6)
# memory usage: 15.4+ MB

# %%
# we want to convert form object to int score of H_team
df['H_score']=pd.to_numeric(df['H_score'])

# %%
# on right side of the RESULT sometimes we can notice some extra information so we can split it by space
# where extra information about RESULT didn't appear we should fill this by NULL
df[['A_score', 'INFO']] = df['A_score'].str.split(' ', expand=True).fillna('')

# %%
# the same instructions as 2 step before - convert result of A_team to int
df['A_score']=pd.to_numeric(df['A_score'])

# %%
# we can check - how much fixtures has some added information 
df['INFO'].value_counts()
# PEN - penatly
# ET - extra time 
# CAN - cancel 
# ABN /AWA - abandoned / awarded 
# WO - walkover
# Out:
#         181133
# PEN.       674
# ET         639
# AWA.       533
# CAN.        22
# ABN.         7
# WO.          1
# Name: INFO, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183009 entries, 0 to 187219
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   COUNTRY      183009 non-null  object
#  1   COMPETITION  183009 non-null  object
#  2   TEAMS        183009 non-null  object
#  3   RESULT       183009 non-null  object
#  4   HOME         130152 non-null  float64
#  5   DRAW         130152 non-null  float64
#  6   AWAY         130152 non-null  float64
#  7   DATE         183009 non-null  datetime64[ns]
#  8   H_score      183009 non-null  int64
#  9   A_score      183009 non-null  int64
#  10  INFO         183009 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 16.8+ MB

# %%
# column RESULT not needed anymore - we split information from this column to another (H_score, A_score and INFO)
df.drop(['RESULT'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    COUNTRY COMPETITION                        TEAMS  HOME   DRAW  AWAY  \
# 0  Germany  bundesliga        Bergischer - Erlangen  1.50   8.58  3.28
# 1  Germany  bundesliga  Flensburg-H. - Rhein-Neckar  1.45   9.37  3.47
# 2  Germany  bundesliga             Goppingen - Kiel  5.54  12.16  1.22
# 3  Germany  bundesliga     Hamm-Westfalen - Leipzig  4.64  10.57  1.29
# 4  Germany  bundesliga   HSG Wetzlar - SC Magdeburg  6.38  12.85  1.18
#
#         DATE  H_score  A_score INFO
# 0 2023-06-11       29       30
# 1 2023-06-11       34       31
# 2 2023-06-11       27       34
# 3 2023-06-11       28       33
# 4 2023-06-11       30       35

# %%
# column known as TEAMS has 2 different team - we want to split it by ' - '
# check that we can split by this expression and get 2 columns
# if this expession not exist exactly 2 times we see value from this row
for index, row in df.iterrows():
    if len(row['TEAMS'].split(' - ')) != 2:
        print(row['TEAMS'])
    else:
        pass

# %%
# we can see that only 4 rows are wrong - "TMBW - Berlin" is problematic so we remove extra spaces in name of this team
df.loc[df['TEAMS'].str.contains('TMBW - Berlin'),'TEAMS'] = df['TEAMS'].str.replace('TMBW - Berlin','TMBW-Berlin')

# %%
df.head()
# Out:
#    COUNTRY COMPETITION                        TEAMS  HOME   DRAW  AWAY  \
# 0  Germany  bundesliga        Bergischer - Erlangen  1.50   8.58  3.28
# 1  Germany  bundesliga  Flensburg-H. - Rhein-Neckar  1.45   9.37  3.47
# 2  Germany  bundesliga             Goppingen - Kiel  5.54  12.16  1.22
# 3  Germany  bundesliga     Hamm-Westfalen - Leipzig  4.64  10.57  1.29
# 4  Germany  bundesliga   HSG Wetzlar - SC Magdeburg  6.38  12.85  1.18
#
#         DATE  H_score  A_score INFO
# 0 2023-06-11       29       30
# 1 2023-06-11       34       31
# 2 2023-06-11       27       34
# 3 2023-06-11       28       33
# 4 2023-06-11       30       35

# %%
# we get 2 extra columns by split TEAMS by expression: ' - '
df[['H_team', 'A_team']] = df['TEAMS'].str.split(' - ',expand=True)

# %%
# column TEAMS not needed anymore - we split information from this column to another (H_team, A_team)
df.drop(['TEAMS'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    COUNTRY COMPETITION  HOME   DRAW  AWAY       DATE  H_score  A_score INFO  \
# 0  Germany  bundesliga  1.50   8.58  3.28 2023-06-11       29       30
# 1  Germany  bundesliga  1.45   9.37  3.47 2023-06-11       34       31
# 2  Germany  bundesliga  5.54  12.16  1.22 2023-06-11       27       34
# 3  Germany  bundesliga  4.64  10.57  1.29 2023-06-11       28       33
# 4  Germany  bundesliga  6.38  12.85  1.18 2023-06-11       30       35
#
#            H_team        A_team
# 0      Bergischer      Erlangen
# 1    Flensburg-H.  Rhein-Neckar
# 2       Goppingen          Kiel
# 3  Hamm-Westfalen       Leipzig
# 4     HSG Wetzlar  SC Magdeburg

# %%
# Country was from dictionary on database so it's correct
# we should check the last thing - competition which came from hyperlink to matches

# %%
# we have 1590 different Competition in our dataset
len(list(df['COMPETITION'].unique()))
# Out:
# 1590

# %%
# we check exmaples of value from column known as COMPETITION
df['COMPETITION'].unique()
# Out:
# array(['Bundesliga', '2 Bundesliga', 'Dhb Pokal', 'Dhb Pokal Women',
#        'Super Cup', 'Super Cup Women', '1 Bundesliga Women',
#        '2 Bundesliga Women', 'Golden League Norway',
#        'Golden League Netherlands Women', 'Ehf Euro Cup', 'European Cup',
#        'European Cup Women', 'European Championship',
#        'European Championship Women', 'Supercopa Iberica',
#        'Golden League Denmark', 'Golden League Denmark Women',
#        'Ehf Euro Cup Women', 'Bene League', 'Ehf Cup', 'Challenge Cup',
#        'Challenge Cup Women', 'Mol Liga Women',
#        'Golden League France Women', 'Golden League France',
#        'Czech Slovak Cup', 'Golden League Norway Women', 'Ehf Cup Women',
#        'Wrhl Women', 'Cup Winners Cup Women', 'Cup Winners Cup',
#        '4 Nations Cup Denmark', 'Handbollsligan', 'Allsvenskan',
#        'She Women', 'Allsvenskan Women', 'Elitserien', 'Santander Cup',
#        'Santander Cup Women', '1 Division Women', 'Herre Handbold Ligaen',
#        '1 Division', 'Hth Ligaen Women', 'Landspokalturnering',
#        'Landspokalturnering Women', 'Nordea Cup', 'Nordea Cup Women',
#        'Jack Jones Ligaen', 'Guldbageren Ligaen Women',
#        'World Championship', 'Friendly International',
#        'Friendly International Women', 'Club Friendly',
#        'Club Friendly Women', 'World Championship U20 Women',
#        'Intersport Cup Women',
#        'South And Central American Championship Women',
#        'World Championship Women', 'Olympic Games', 'Olympic Games Women',
#        'South And Central American Championship',
#        'Ihf Emerging Nations Championship', 'World Championship U21',
#        'Mobelringen Cup Women', 'Pan American Club Championship',
#        'Tournoi De Paris', 'Gf World Cup Women', 'Copa Asobal',
#        'Copa De La Reina Women', 'Copa Del Rey', 'Supercopa Women',
#        'Division De Honor Women', 'Supercopa', 'Liga Asobal',
#        'Division De Honor Plata', 'Abf Women', 'Starligue',
#        'Coupe De France', 'Division 1 Women', 'Coupe De France Women',
#        'Trophee Des Champions', 'Coupe De La Ligue', 'Proligue',
#        'Coupe De La Ligue Women', 'Division 1', 'Romanian Cup',
#        'Romanian Cup Women', 'Liga Nationala', 'Liga Nationala Women',
#        'Polish Cup', 'I Liga Women', 'Polish Cup Women', 'Superliga',
#        'Central League', 'Superliga Women', 'Ekstraklasa', 'Ohb Cup',
#        'Ohb Cup Women', 'Supercup', 'Wha Women', 'Gcc Games',
#        'Premijer Liga', 'A Rhg', '1 Hrl Women', 'Dukat Premijer Liga',
#        'Czech Cup', 'Extraliga Women', 'Czech Cup Women', 'Extraliga',
#        'Meistriliiga', 'Suomen Cup', 'Suomen Cup Women', 'Greek Cup',
#        'A1', 'Hungarian Cup', 'Nb I Women', 'Hungarian Cup Women', 'Nb I',
#        'Olis Deildin', 'Olis Deild Women', 'Coppa Italia',
#        'Coppa Italia Women', 'Serie A', 'Serie A Women', 'Lietuvos Lyga',
#        '1St Division', 'Prva Liga', 'Eredivisie', 'Eredivisie Women',
#        'Superleague Women', 'Superleague', 'Nm Cup', 'Nm Cup Women',
#        'Rema  Ligaen 2019 2020', 'Rema  Ligaen Women 2019 2020',
#        'Taca De Portugal', 'Russian Cup', 'Russian Cup Women',
#        'Supercup Women', 'Slovakia Cup', '1 Nlb Lig', 'Slovenian Cup',
#        '1 A Drl Women', 'Mik 1 Liga', '1St League Women', '1St League',
#        'Schweizer Cup', 'Schweizer Cup Women', 'Nla', 'Spl Women',
#        'Superlig', 'Superlig Women', 'Champions League',
#        'Champions League Women', 'European League',
#        'European League Women', 'Baltic League', 'Seha Liga',
#        'European Championship U20', 'European Championship U20 B',
#        'European Championship U18', 'European Championship U18 B',
#        'Ihf Ehf Trophy', 'European Championship U19',
#        'European Championship U19 B', 'European Championship U19 Women',
#        'European Championship U19 B Women',
#        'European Championship U17 Women',
#        'European Championship U17 B Women', 'Ehf Challenge Trophy Women',
#        'Whil Women', 'Ihf Ehf Trophy Women', 'Swedish Cup',
#        'Swedish Cup Women', 'Elitserien Women', 'Kvindeligaen Women',
#        'Bambusa Kvindeligaen Women', '888Ligaen', 'Hth Go Ligaen Women',
#        'Primo Tours Ligaen Women', 'Boxer Herreligaen',
#        'Boxer Dameligaen Women', 'Handbold Ligaen',
#        'World Championship U18 Women', 'Mediterranean Games',
#        'Mediterranean Games Women', 'Super Globe',
#        'World Championship U19', 'Pan American Games',
#        'Pan American Games Women', 'Super Globe Women',
#        'Pan American Championship', 'Pan American Championship Women',
#        'Pan American Club Championship Women', 'Universiade',
#        'Universiade Women', 'I Liga',
#        'Central American Caribbean Games Women', 'Hla',
#        'African Championship', 'African Championship Women',
#        'Asian Championship', 'Asian Championship Women', 'Asian Games',
#        'Asian Games Women', 'Czech Slovak Handball League', 'Sm Sarja',
#        'Sm Sarja Women', 'N1 Deild', 'A Elite', 'Jhl Women', 'Jhl',
#        'Virsliga', 'Synottip Virsliga', 'Axa League',
#        'Sales Lentz League', 'Handbalnl League',
#        'Central American Caribbean Games', 'Rema  Ligaen 2022 2023',
#        'Rema  Ligaen Women 2022 2023', 'Rema  Ligaen 2021 2022',
#        'Rema  Ligaen Women 2021 2022', 'Rema  Ligaen 2020 2021',
#        'Rema  Ligaen Women 2020 2021', 'Grundigligaen',
#        'Grundigligaen Women', 'Postenligaen', 'Postenligaen Women',
#        'Andebol 1', '1A Divisao Women', 'Lpa', 'Arkus Liga',
#        'Arkus Liga Women', '1 A Rl'], dtype=object)

# %%
# we define pattern to extract SEASON which is on the end COMPETITION
pattern = r'\b(\d{4}(?:-\d{4})?)\b'
# Tworzenie nowej zmiennej
df['SEASON'] = df['COMPETITION'].str.extract(pattern)

# %%
# delete values which are now in column SEASON
for index, row in df.iterrows():
    df.at[index, 'COMPETITION'] = row['COMPETITION'].replace(str(row['SEASON']), '')

# %%
# Replace '-' by space, title and strip values
df['COMPETITION'] = df['COMPETITION'].str.replace('-',' ').str.title().str.strip()

# %%
df
# Out:
#         COUNTRY  COMPETITION  HOME   DRAW  AWAY       DATE  H_score  A_score  \
# 0       Germany   Bundesliga  1.50   8.58  3.28 2023-06-11       29       30
# 1       Germany   Bundesliga  1.45   9.37  3.47 2023-06-11       34       31
# 2       Germany   Bundesliga  5.54  12.16  1.22 2023-06-11       27       34
# 3       Germany   Bundesliga  4.64  10.57  1.29 2023-06-11       28       33
# 4       Germany   Bundesliga  6.38  12.85  1.18 2023-06-11       30       35
# ...         ...          ...   ...    ...   ...        ...      ...      ...
# 187215  Ukraine  Superleague  4.20  11.00  1.28 2013-05-25       24       37
# 187216  Ukraine  Superleague   NaN    NaN   NaN 2013-05-19       32       29
# 187217  Ukraine  Superleague   NaN    NaN   NaN 2013-05-19       27       17
# 187218  Ukraine  Superleague   NaN    NaN   NaN 2013-05-14       24       30
# 187219  Ukraine  Superleague   NaN    NaN   NaN 2013-05-14       25       28
#
#        INFO            H_team            A_team     SEASON
# 0                  Bergischer          Erlangen        NaN
# 1                Flensburg-H.      Rhein-Neckar        NaN
# 2                   Goppingen              Kiel        NaN
# 3              Hamm-Westfalen           Leipzig        NaN
# 4                 HSG Wetzlar      SC Magdeburg        NaN
# ...     ...               ...               ...        ...
# 187215         Dinamo Poltava          Portovik  2012-2013
# 187216       Motor Zaporozhye          Portovik  2012-2013
# 187217         ZTR Zaporozhye    Dinamo Poltava  2012-2013
# 187218         Dinamo Poltava    ZTR Zaporozhye  2012-2013
# 187219               Portovik  Motor Zaporozhye  2012-2013
#
# [183009 rows x 12 columns]

# %%
# define new order in DataFrame
new_order = ['COUNTRY', 'COMPETITION', 'SEASON','H_team','A_team','H_score','A_score','RESULT','INFO','HOME','DRAW','AWAY','DATE']
df = df.reindex(columns=new_order)

# %%
# matches from 2023 should be markes as SEASON 2022-2023 / this info wasn't in hyperlink
df.loc[df['DATE'].dt.year == 2023,'SEASON'] = '2022-2023'

# %%
# we still get some NaN value in SEASON because this was a first part of season 2022-2023
df.loc[df['SEASON'].isna()]
# Out:
#         COUNTRY  COMPETITION SEASON             H_team            A_team  \
# 146     Germany   Bundesliga    NaN           Erlangen         Stuttgart
# 147     Germany   Bundesliga    NaN       Flensburg-H.       HSG Wetzlar
# 148     Germany   Bundesliga    NaN      Fuchse Berlin           Leipzig
# 149     Germany   Bundesliga    NaN        Gummersbach           Hamburg
# 150     Germany   Bundesliga    NaN  Hannover-Burgdorf        Bergischer
# ...         ...          ...    ...                ...               ...
# 186597  Ukraine  Superleague    NaN           SKA Lviv   Donbas Mariupol
# 186598  Ukraine  Superleague    NaN          CSKA Kiev  Karpaty Uzhgorod
# 186599  Ukraine  Superleague    NaN             Odessa   Donbas Mariupol
# 186600  Ukraine  Superleague    NaN           SKA Lviv         CSKA Kiev
# 186601  Ukraine  Superleague    NaN   Karpaty Uzhgorod          SKA Lviv
#
#         H_score  A_score INFO  HOME   DRAW   AWAY       DATE
# 146          31       28       1.41   9.50   3.73 2022-12-27
# 147          34       24       1.08  17.19  10.25 2022-12-27
# 148          28       22       1.20  13.02   6.00 2022-12-27
# 149          31       30       1.75   8.17   2.57 2022-12-27
# 150          30       32       1.40   9.28   3.86 2022-12-27
# ...         ...      ...  ...   ...    ...    ...        ...
# 186597       22       40        NaN    NaN    NaN 2022-11-11
# 186598       30       25        NaN    NaN    NaN 2022-10-23
# 186599       24       33        NaN    NaN    NaN 2022-10-22
# 186600       26       34        NaN    NaN    NaN 2022-10-22
# 186601       31       23        NaN    NaN    NaN 2022-10-21
#
# [7496 rows x 12 columns]

# %%
# we put value '2022-2023' in SEASON where is still NaN and DATE was from year 2022
df.loc[((df['DATE'].dt.year == 2022) & (df['SEASON'].isna())),'SEASON'] = '2022-2023'

# %%
# every season was filled
df['SEASON'].unique()
# Out:
# array(['2022-2023', '2021-2022', '2021', '2020-2021', '2020', '2019-2020',
#        '2019', '2018-2019', '2018', '2017-2018', '2017', '2016-2017',
#        '2016', '2015-2016', '2015', '2014-2015', '2014', '2013-2014',
#        '2013', '2012-2013', '2012', '2011-2012', '2011', '2010-2011',
#        '2009-2010', '2008-2009', '2007-2008', '2006-2007', '2005-2006',
#        '2004-2005', '2003-2004', '2002-2003', '2001-2002', '2000-2001',
#        '2022', nan, '2009', '2010', '2008', '1000', '2006', '2004',
#        '2002', '2000', '1998', '2007', '2005', '2003', '2001', '1999',
#        '1999-2000', '1998-1999'], dtype=object)

# %%
# create RESULT - dependencies on score
df.loc[df['H_score']>df['A_score'],'RESULT'] = 'H'

# %%
df.loc[df['H_score']<df['A_score'],'RESULT'] = 'A'

# %%
df.loc[df['H_score']==df['A_score'],'RESULT'] = 'D'

# %%
df.head(15)
# Out:
#     COUNTRY COMPETITION     SEASON             H_team             A_team  \
# 0   Germany  Bundesliga  2022-2023         Bergischer           Erlangen
# 1   Germany  Bundesliga  2022-2023       Flensburg-H.       Rhein-Neckar
# 2   Germany  Bundesliga  2022-2023          Goppingen               Kiel
# 3   Germany  Bundesliga  2022-2023     Hamm-Westfalen            Leipzig
# 4   Germany  Bundesliga  2022-2023        HSG Wetzlar       SC Magdeburg
# 5   Germany  Bundesliga  2022-2023            Hamburg       MT Melsungen
# 6   Germany  Bundesliga  2022-2023              Lemgo      Fuchse Berlin
# 7   Germany  Bundesliga  2022-2023             Minden        Gummersbach
# 8   Germany  Bundesliga  2022-2023          Stuttgart  Hannover-Burgdorf
# 9   Germany  Bundesliga  2022-2023           Erlangen       Flensburg-H.
# 10  Germany  Bundesliga  2022-2023        Gummersbach          Goppingen
# 11  Germany  Bundesliga  2022-2023  Hannover-Burgdorf             Minden
# 12  Germany  Bundesliga  2022-2023       SC Magdeburg          Stuttgart
# 13  Germany  Bundesliga  2022-2023      Fuchse Berlin            Hamburg
# 14  Germany  Bundesliga  2022-2023               Kiel        HSG Wetzlar
#
#     H_score  A_score INFO  HOME   DRAW   AWAY       DATE RESULT
# 0        29       30       1.50   8.58   3.28 2023-06-11      A
# 1        34       31       1.45   9.37   3.47 2023-06-11      H
# 2        27       34       5.54  12.16   1.22 2023-06-11      A
# 3        28       33       4.64  10.57   1.29 2023-06-11      A
# 4        30       35       6.38  12.85   1.18 2023-06-11      A
# 5        33       28       1.67   7.93   2.78 2023-06-11      H
# 6        35       32       3.37   9.04   1.47 2023-06-11      H
# 7        38       38       3.18   8.68   1.52 2023-06-11      D
# 8        31       34       3.19   8.68   1.52 2023-06-11      A
# 9        28       33       5.41  11.03   1.24 2023-06-08      A
# 10       35       32       1.65   8.05   2.82 2023-06-08      H
# 11       32       19       1.12  14.62   8.66 2023-06-08      H
# 12       31       27       1.07  18.26  11.39 2023-06-08      H
# 13       36       32       1.17  13.22   6.59 2023-06-07      H
# 14       38       23       1.07  16.12  12.15 2023-06-07      H

# %%
# define new order in DataFrame
new_order = ['COUNTRY', 'COMPETITION', 'SEASON','H_team','A_team','H_score','A_score','RESULT','INFO','HOME','DRAW','AWAY','DATE']
df = df.reindex(columns=new_order)

# %%
df.head()
# Out:
#    COUNTRY COMPETITION     SEASON          H_team        A_team  H_score  \
# 0  Germany  Bundesliga  2022-2023      Bergischer      Erlangen       29
# 1  Germany  Bundesliga  2022-2023    Flensburg-H.  Rhein-Neckar       34
# 2  Germany  Bundesliga  2022-2023       Goppingen          Kiel       27
# 3  Germany  Bundesliga  2022-2023  Hamm-Westfalen       Leipzig       28
# 4  Germany  Bundesliga  2022-2023     HSG Wetzlar  SC Magdeburg       30
#
#    A_score RESULT INFO  HOME   DRAW  AWAY       DATE
# 0       30      A       1.50   8.58  3.28 2023-06-11
# 1       31      H       1.45   9.37  3.47 2023-06-11
# 2       34      A       5.54  12.16  1.22 2023-06-11
# 3       33      A       4.64  10.57  1.29 2023-06-11
# 4       35      A       6.38  12.85  1.18 2023-06-11

# %%
# save the file
df.to_csv('handball.csv', index=False)
